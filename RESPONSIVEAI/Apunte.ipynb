# %% [markdown]
# # Responsive AI

# %% [markdown]
# ### Sev
#
# Severidad del bug.
#
# ### 1 SEV
# Significa que valio vrga todos y que solo DIOS sabe que hacer.
#
#
#
# - Los modelos sencicllos son intrinsicamente interpetrables: Como regresiones.
#
# Aqui en responsive AI se identificaran porque los modelos deciden lo que deciden .
#
#
# En hugging face.
#
#
# Distilbert
#
# Es para analisis de sentimientos, le damos un texto y este decide si es algo positivo o negativo.

# %% [markdown]
# # CLASE 10 DE JULIO
#
# ## ETICA Y DISEÑO CENTRADO EN EL HUMANO
#
# EQUIDAD
#
# - Las predicciones estan libres de sesgos discerribles.
#
# Todo los modelos deben incluir caras de NIGGAS.
#
#
#
# RESPONSABILIDAD
#
# Todas las huevadas que hagas. Te haces responsables.
#
# TRANSPARENCIA
#
# Decir todas las verdades, no mentir ahuvonado.
#
# ### FISICAL AI
#
# Darle un cuerpo a un modelo.

# %% [markdown]
# # CLASE DE 15 DE JULIO
#
# Riegos de AI
# - Segos
# - Privacidad
# - Seguridad
# - Transparencia
# - Autonomia
#
# CI/CD Probar todoi lo que hacemos y deployamos
#
# EN temas de AI hay otro llamado CI/CD/CT
#
# PEP 8: ESTILO PARA CODIFICAR EN PYTHON.
#
#
#
# # Diseñadores de Producto
#
# - Mapeo
# - Medición
# - Manejo
#
# Estos 3 son manejados por producto.
#
#
#
# ## Sesgo en Gneral
#
# Complejidad alta;
#
# El sesgo puede provenir de multiples fuentes, incluyendo datos, algoritmos y la interpretación humana.
#
# Diferentes tipos de sego pueden interactuar y exacerbarse mutuamente.
#
# SESGOS
# - HISTORICO
# - REPRESENTACION
# - MEDICIONES
# - AGREGACION
# - EVALUACION
# - DEPLOYMENT
# -

# %% [markdown]
# ## PROYECTO 1
