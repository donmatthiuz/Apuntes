# %% [markdown]
# ![image.png](attachment:image.png)
#
# La funcion identidad de una uniforme lo que queremos es generar valores entre
#
# 1 a n
#
# Lo que queremos es que el histograma de probabilidades queden iguales
#
# ![image-2.png](attachment:image-2.png)
#
#
# Lo que hace uno es empaquetar bits en paquetes generar floats y luego numeros enteros.
#
# ![image-3.png](attachment:image-3.png)
#
#
# y luego mod n para llevarlos a decimal.

# %% [markdown]
# ## Clase 28102025
#
# ![Notas_page-0004.jpg](attachment:Notas_page-0004.jpg)
#
# ![Notas_page-0001.jpg](attachment:Notas_page-0001.jpg)
#
# ![Notas_page-0002.jpg](attachment:Notas_page-0002.jpg)
#
# ![Notas_page-0003.jpg](attachment:Notas_page-0003.jpg)
