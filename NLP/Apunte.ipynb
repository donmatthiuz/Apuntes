# %% [markdown]
# # CLASE DE 9 DE JULIO

# %% [markdown]
# ## Modelo fundacionales
#
# Todos los que conocemos GPT .5 , FABLE 5
#
# Son modelos que crean sus propias capas .
#
#
# El modelo fundacional: SOn capaces de ppredecir antes de que te des cuenta.
#
# ### NLP
#
# Son la tokenizacion, cada modelo esta optimizado para obtener capas o no. Pueden haber tokens de N cantidad.
#
# Luego llega la vectorización, bases vectoriales. Aws tiene kendra, embedings son el conjunto de vectores para ver que se asemeja a lo que vamos encontrando.
#
# Correlación, distancias ecludianas despues seguirian para que empiece a relacionar .  Parte bastante importante del procesamiento es esto. El objetivo del curso es hacer un LLM.
#
#
#
# Lo que tenemos que hacer es fine tunning de los modelos y empezar a hacer la ingesta de datos.
#
#
# Blende: Teorica y Practica que no es presencial.
#
#
#
#
# - LLM STUDIO Como GEMA que son los modelos livianos de google.
#
#
#
# ## EL PRIMER MES ES FULL PRESENCIAL. LOS DIAS JUEVES DEDSDE CASA EN AGOSTO.

# %% [markdown]
# # CLASE 16 DE JULIO
#
# - Documento: Unidad individual de un corpus
# - Corpus: Coleccion de textos
# - Oracion: Segmento linguistico ocn cierta unidad semantica
# - Token: Unidad minima que el sistema procesara
# - Vocabulario: Conjunto de tokens conocidos
# - Tokenizador: Algoritmo que convierte texto en tokens.

# %% [markdown]
# Un token:
#
# Un sigono, una palabra, un numero , un caracter, un signo , una subpalabra un simbolo especial.
#
#
#
# ## Actividad Corta:
#
# Hola!!! Mi correo es ana.lopez@uvg.edu.gt y necesito ayuda urgente:
#
#
# - El emogi se puede llegar a quitar porque ya existe lo demas que demuestra que es urgente.
#
#
#
# - Tokenizacion clasica
#
# Solo se hacia el split xd .  La ventaja es que es facil de entender y para tareas simples, las limitaciones es que no majea bien la puntuación, faltan con correos , urls o amogis, no resuelve palabras desconocidas.
#
#
# ### Regex
#
# Con esta lo hacemos con regex. Asi encontramos patrones.
#
#
# ### Normalizacion
#
# Convertir minusculas, quitar espacios, unificar saltos, remover caracteres invisibles, estandarizar comillas o simbolos.
#
#
#
# ## Poruqe importa la tokenizacion
#
# El costo de uso de apis
# El limite de contexto.
# El trato de idiomas distintos al ingles.
# La representación de pas raras
# La exposicion accidental.
#
#
#
# ## Pregunta de discusion
#
# Si vamos a detectar datos sensibles nos conviene tokenizar antes o despues de detectar esot.
#
# La mejor estrategia es mejor hacerlo antes, porque asi lo evitamos desde antes de evitar que llegue algo
#
#
# El preprocesamiento como pipeline
#
# - Entrada de usuario
# - Normalizacion minima
# - Deteccion de datos sensibles
# - Accion de gardrails
# - Tokenizacion
# - Estadisticas
# - Salida al modelo o bloqueo
#
#
#
# ## Guardrail
#
# Es una capa de control que reduce riesgos antes o despues de usar un modelo sirve para
#
# bloquear entradas
# redactar datos sensibles
# advertir al usuario
# validar formato de salida
# evitar fuga de informacion
# reducir prompt inyection
#
#
# ## Regex porque usar
#
# Entender patrones complicados
