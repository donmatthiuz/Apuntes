# %% [markdown]
# # APUNTES 6 DE JULIO DEL 2026

# %% [markdown]
# TAREAS
#
# - INVESTIGACION + PRESENTACIONES
#
# TALLERES
# - EMPAQUETACION DE CODIGO Y USO DE LA NUBRE.
#
# CASOS DE ESTUDIO
#
# - SITUACIONES REALES DE COSAS PASADAS EN EL BANCO.
#
#
# PORTAFOLIO
#
# - TENER UNA PAGINA EN LA QUE TENGAN LAS ACTIVIDADES DEL CURSO . PARA BUSCAR CHAMBA.
#
#
#
#
# PROYECTO FINAL
#
# SOLUCION SOBRE ALGO QUE ESTEMOS TRABAJANDO O NECESITEMOS. INCLUSO VAN A TRAER COMPAÑEROS DEL BANCO PARA EVALUAR.
#
#
#
# VAMOS A EMPAQUETAR NUESTRO CODIGO Y LO VAMOS A PUBLICAR EN PYPI
#
#
# PLATAFORMAS
#
# - AZURE
# - DATABRICKS

# %% [markdown]
# #  CLASE DE 10 DE JULIO
#
# ## CRISP - DM
#
# Aqui no se menciona nada de IA, solo se mencionan datos.
#
# ![image.png](attachment:image.png)
#
# La idea es llegar al despligue, y es el oro de todo lo que es la IA.
#
#
# Algo que pasa con los modelos es que pasamos por diferentes etapas se coloca el modelo con la version1.  Eso esta malo porque no hay trazabilidad ni las actualizaciones son recurrentes.
#
# Los datos como se van generando cambian mas rapido. Estar en un movimiento diario es parte.
#
# Se sigue dando en los bancos cuando la generación de esos datos fallan hay 5 o 6 modelos sin monitorear.
#
# Porque si no hay un flujo no sirve de nada .
#
#
# ## CHISP MLQ
#
# ![image-3.png](attachment:image-3.png)
#
#
# Incluye validaciones de
# - datos
# - modelos
# - recursos
#
# ![image-2.png](attachment:image-2.png)
#
#
# Tambien esta la parte que sirve de insumo para el modelo.
#
# Yo despliego mis recursos, pero le da mantenimiento. Aqui un cientifico en mantenimiento no tiene ni vrg que ver pero un ingeniero si .
#
#
# ## EL RUMBO
#
# Si no sabes a donde mrd ir pues no vale munda que hacer.
#
#
#
# Loo que pasa mucho es lo que me paso a mi con el prro CIAM, maldita sea. Todos tienen guardado todo en todas partes y sin documentacion y cuando uno quiere buscar una tabla ni sepa judas donde esta o la truncaron. Que bola de inutiles son los godinez de TODOS LOS BANCOS . Solo unos pocos le saben jajaja.
#
#
#
# ## Entendimiento del negocio
#
# - GIRO DEL NEGOCIO
# UVG: Generar profesionales.
#
# - PROCESOS DEL NEGOCIO
#
# }
# - RETOS DEL NEGOCIO
#
#
#
# Muchas veces para entender el negocio de BMC. Osea el prro business model canvas , pinche Pablo lo odio vale vrg.
#
# El modelo es solo un complmento , hay que ver que soluciona o que ayuda al negocio siguiendo el BMC del pinche Pablo.
#
#
#
#
#
# ### Entendimiento de los datos
#
#
# - DONDE VRG ESTA
#
# - TIPOS
#
# - SIGNIFICADO DEL PROCESOS DE NEGOCIO
#
# - ANALISIS EXPLORATORIO EDA.
#
#
#
# Una cosa esta en que la manera en como expresar al negocio nuestras ideas, porque son gente medio lenta y solo buscan la manera en como ahorrar ](aunque a veces ni lo logran).
#
# El cientifico de datos no genera modelos, pero en realidad, a lo que se dedica mas que todo es a encontrar patrones de datos, despues se puede evaluar si se hacen
#
# - MODELO
# - PIPELINE
# - TABLERO.
#
# ETC.
#
# Osea que lo que hacen en el trabajo si esta bien desempeñado su valor, no es de tirar modelos al azar.
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# ## Hubo un problema.
#
# Desplegaron un modelo , y valior vrg en todos los meses excepto semana santa, por la estacionalidad de las ventas. Como junio, mayo, etc.
#
# Ese tipo de patrones es muy importante reconocerlos. El problema es que los que vendieron el modelo solo tomaron como muestra semana santa y valio vrg.
#
#
#
# ### Datos
#
# - CALIDAD
# - CONSISTENCIA QUE SIEMPRE SE GENERE
# - VALORES NEGATIVOS O FUERA DE RANGOS.
# - CHECKS DE DATOS.
#
#
# Ahora ya preparado analizado, yh teniendo la información. Podemos generar features. Por eso LA CAGADA VA EN LA TAZA.
#
# Lo que queremos hacer es algo mas preciso y definado, ir mejorando los modelos, no podemos eguir usando lo mismo.
